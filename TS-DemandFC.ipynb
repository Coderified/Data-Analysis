# %%
import dask
dask.config.set({"dataframe.query-planning": True})
import pandas

# %%
import lightgbm as lgb
print(lgb.__version__)
# Out:
# 4.6.0

# %%
import itertools
import pandas as pd
import numpy as np
from random import gauss,shuffle

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import het_arch, acorr_ljungbox

'''
het_arch - (ARCH Test)
Purpose: Tests for Autoregressive Conditional Heteroskedasticity (ARCH) effects in the residuals of a time series model.
Usage: Helps detect volatility clustering (common in financial time series).
Null Hypothesis (H₀): No ARCH effects (residuals are homoskedastic).
Alternative Hypothesis (H₁): ARCH effects exist (residuals are heteroskedastic).
Output: Test statistic and p-value. If p-value < significance level (e.g., 0.05), reject H₀.

 (Ljung-Box Test)
Purpose: Tests whether autocorrelations in the residuals of a time series model are zero (no serial correlation).
Usage: Checks for remaining structure in residuals after fitting a model (e.g., ARIMA).
Null Hypothesis (H₀): No autocorrelation up to lag lags.
Alternative Hypothesis (H₁): Autocorrelation exists.
Output: Test statistic and p-value for each lag. Small p-values indicate significant autocorrelation.
'''

from sklearn.metrics import mean_absolute_error as mae ,mean_absolute_percentage_error as mape ,mean_squared_error as mse
from scipy.stats import shapiro, probplot
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.multioutput import MultiOutputRegressor
from sklearn.cluster import KMeans

import os
# import lightgbm as lgb

from datetime import datetime, timedelta
import gc,copy

from gensim.models import Word2Vec

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 

import warnings
warnings.filterwarnings("ignore")

# %%
#Adjust displayed images size
plt.rcParams.update({'figure.figsize':(20,10)})

# %%
# pip install --upgrade jupyter

# %%
df=pd.read_csv("C:/Users/bhara/Downloads/m5-forecasting-accuracy/sales_train_validation.csv")
df = df.loc[df.state_id == 'CA']
df.head(5)
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
# 2       CA    0    0    0    0  ...       2       1       2       1       1
# 3       CA    0    0    0    0  ...       1       0       5       4       1
# 4       CA    0    0    0    0  ...       2       1       1       0       1
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# 0       1       3       0       1       1
# 1       1       0       0       0       0
# 2       1       0       1       1       1
# 3       0       1       3       7       2
# 4       1       2       2       2       4
#
# [5 rows x 1919 columns]

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df


df = reduce_mem_usage(df)
# Out:
# Memory usage of dataframe is 178.65 MB
# Memory usage after optimization is: 35.74 MB
# Decreased by 80.0%

# %%
df.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd_1',
#        'd_2', 'd_3', 'd_4',
#        ...
#        'd_1904', 'd_1905', 'd_1906', 'd_1907', 'd_1908', 'd_1909', 'd_1910',
#        'd_1911', 'd_1912', 'd_1913'],
#       dtype='object', length=1919)

# %% [markdown]
# # UnPivotting

# %%
df = pd.melt(df,id_vars=['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'],var_name="d",value_name="Sales").dropna()

# %%
df.head(10)
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
# 5  HOBBIES_1_006_CA_1_validation  HOBBIES_1_006  HOBBIES_1  HOBBIES     CA_1
# 6  HOBBIES_1_007_CA_1_validation  HOBBIES_1_007  HOBBIES_1  HOBBIES     CA_1
# 7  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1
# 8  HOBBIES_1_009_CA_1_validation  HOBBIES_1_009  HOBBIES_1  HOBBIES     CA_1
# 9  HOBBIES_1_010_CA_1_validation  HOBBIES_1_010  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  Sales
# 0       CA  d_1      0
# 1       CA  d_1      0
# 2       CA  d_1      0
# 3       CA  d_1      0
# 4       CA  d_1      0
# 5       CA  d_1      0
# 6       CA  d_1      0
# 7       CA  d_1     12
# 8       CA  d_1      2
# 9       CA  d_1      0

# %%
cal = pd.read_csv("C:/Users/bhara/Downloads/m5-forecasting-accuracy/calendar.csv")

# %%
cal.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
df=pd.merge(df,cal,on="d",how='left')
del cal

# %%
df.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd',
#        'Sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI'],
#       dtype='object')

# %%
df.drop(['d','wm_yr_wk', 'weekday', 'month', 'year',
       'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap_TX', 'snap_WI'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  Sales        date  wday  snap_CA
# 0       CA      0  2011-01-29     1        0
# 1       CA      0  2011-01-29     1        0
# 2       CA      0  2011-01-29     1        0
# 3       CA      0  2011-01-29     1        0
# 4       CA      0  2011-01-29     1        0

# %%
df1 = df.loc[df['item_id']=='HOBBIES_1_195'][['date','Sales']].copy()
df1.set_index("date").Sales.plot()
plt.show()

# %% [markdown]
# # Generate Features to convert into a reg based FC

# %%
df["Lag_28"] = df[["id","Sales"]].groupby("id")["Sales"].shift(28).fillna(-1)

# %%
df[df["id"]=="HOBBIES_1_001_CA_1_validation"].tail()
# Out:
#                                      id        item_id    dept_id   cat_id  \
# 23269968  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 23282164  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 23294360  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 23306556  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 23318752  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
#
#          store_id state_id  Sales        date  wday  snap_CA  Lag_28
# 23269968     CA_1       CA      1  2016-04-20     5        0     2.0
# 23282164     CA_1       CA      3  2016-04-21     6        0     0.0
# 23294360     CA_1       CA      0  2016-04-22     7        0     1.0
# 23306556     CA_1       CA      1  2016-04-23     1        0     1.0
# 23318752     CA_1       CA      1  2016-04-24     2        0     1.0

# %%
df["rmean_7_lag28"]=df[["id","Lag_28"]].groupby("id")["Lag_28"].transform(lambda x:x.rolling(7).mean()).fillna(-1)
df["rmean_28_lag28"]=df[["id","Lag_28"]].groupby("id")["Lag_28"].transform(lambda x:x.rolling(28).mean()).fillna(-1)

# %%
df.tail(10)
# Out:
#                                    id      item_id  dept_id cat_id store_id  \
# 23330938  FOODS_3_818_CA_4_validation  FOODS_3_818  FOODS_3  FOODS     CA_4
# 23330939  FOODS_3_819_CA_4_validation  FOODS_3_819  FOODS_3  FOODS     CA_4
# 23330940  FOODS_3_820_CA_4_validation  FOODS_3_820  FOODS_3  FOODS     CA_4
# 23330941  FOODS_3_821_CA_4_validation  FOODS_3_821  FOODS_3  FOODS     CA_4
# 23330942  FOODS_3_822_CA_4_validation  FOODS_3_822  FOODS_3  FOODS     CA_4
# 23330943  FOODS_3_823_CA_4_validation  FOODS_3_823  FOODS_3  FOODS     CA_4
# 23330944  FOODS_3_824_CA_4_validation  FOODS_3_824  FOODS_3  FOODS     CA_4
# 23330945  FOODS_3_825_CA_4_validation  FOODS_3_825  FOODS_3  FOODS     CA_4
# 23330946  FOODS_3_826_CA_4_validation  FOODS_3_826  FOODS_3  FOODS     CA_4
# 23330947  FOODS_3_827_CA_4_validation  FOODS_3_827  FOODS_3  FOODS     CA_4
#
#          state_id  Sales        date  wday  snap_CA  Lag_28  rmean_7_lag28  \
# 23330938       CA      5  2016-04-24     2        0     1.0       3.000000
# 23330939       CA      0  2016-04-24     2        0     2.0       0.714286
# 23330940       CA      3  2016-04-24     2        0     1.0       0.714286
# 23330941       CA      0  2016-04-24     2        0     0.0       0.571429
# 23330942       CA      2  2016-04-24     2        0     0.0       0.571429
# 23330943       CA      0  2016-04-24     2        0     0.0       0.000000
# 23330944       CA      1  2016-04-24     2        0     0.0       0.000000
# 23330945       CA      0  2016-04-24     2        0     0.0       0.285714
# 23330946       CA      4  2016-04-24     2        0     2.0       1.857143
# 23330947       CA      8  2016-04-24     2        0     0.0       1.000000
#
#           rmean_28_lag28
# 23330938        3.500000
# 23330939        0.535714
# 23330940        1.000000
# 23330941        0.428571
# 23330942        0.642857
# 23330943        0.607143
# 23330944        0.000000
# 23330945        0.642857
# 23330946        2.107143
# 23330947        0.857143

# %%
df[df["id"]=="FOODS_1_001_CA_1_validation"].head(35)
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 1612    FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 13808   FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 26004   FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 38200   FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 50396   FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 62592   FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 74788   FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 86984   FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 99180   FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 111376  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 123572  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 135768  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 147964  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 160160  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 172356  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 184552  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 196748  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 208944  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 221140  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 233336  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 245532  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 257728  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 269924  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 282120  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 294316  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 306512  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 318708  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 330904  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 343100  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 355296  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 367492  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 379688  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 391884  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 404080  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 416276  FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
#
#        state_id  Sales        date  wday  snap_CA  Lag_28  rmean_7_lag28  \
# 1612         CA      3  2011-01-29     1        0    -1.0      -1.000000
# 13808        CA      0  2011-01-30     2        0    -1.0      -1.000000
# 26004        CA      0  2011-01-31     3        0    -1.0      -1.000000
# 38200        CA      1  2011-02-01     4        1    -1.0      -1.000000
# 50396        CA      4  2011-02-02     5        1    -1.0      -1.000000
# 62592        CA      2  2011-02-03     6        1    -1.0      -1.000000
# 74788        CA      0  2011-02-04     7        1    -1.0      -1.000000
# 86984        CA      2  2011-02-05     1        1    -1.0      -1.000000
# 99180        CA      0  2011-02-06     2        1    -1.0      -1.000000
# 111376       CA      0  2011-02-07     3        1    -1.0      -1.000000
# 123572       CA      0  2011-02-08     4        1    -1.0      -1.000000
# 135768       CA      0  2011-02-09     5        1    -1.0      -1.000000
# 147964       CA      3  2011-02-10     6        1    -1.0      -1.000000
# 160160       CA      1  2011-02-11     7        0    -1.0      -1.000000
# 172356       CA      3  2011-02-12     1        0    -1.0      -1.000000
# 184552       CA      0  2011-02-13     2        0    -1.0      -1.000000
# 196748       CA      2  2011-02-14     3        0    -1.0      -1.000000
# 208944       CA      1  2011-02-15     4        0    -1.0      -1.000000
# 221140       CA      2  2011-02-16     5        0    -1.0      -1.000000
# 233336       CA      0  2011-02-17     6        0    -1.0      -1.000000
# 245532       CA      2  2011-02-18     7        0    -1.0      -1.000000
# 257728       CA      1  2011-02-19     1        0    -1.0      -1.000000
# 269924       CA      2  2011-02-20     2        0    -1.0      -1.000000
# 282120       CA      0  2011-02-21     3        0    -1.0      -1.000000
# 294316       CA      2  2011-02-22     4        0    -1.0      -1.000000
# 306512       CA      2  2011-02-23     5        0    -1.0      -1.000000
# 318708       CA      2  2011-02-24     6        0    -1.0      -1.000000
# 330904       CA      4  2011-02-25     7        0    -1.0      -1.000000
# 343100       CA      2  2011-02-26     1        0     3.0      -0.428571
# 355296       CA      2  2011-02-27     2        0     0.0      -0.285714
# 367492       CA      0  2011-02-28     3        0     0.0      -0.142857
# 379688       CA      2  2011-03-01     4        1     1.0       0.142857
# 391884       CA      1  2011-03-02     5        1     4.0       0.857143
# 404080       CA      7  2011-03-03     6        1     2.0       1.285714
# 416276       CA      1  2011-03-04     7        1     0.0       1.428571
#
#         rmean_28_lag28
# 1612         -1.000000
# 13808        -1.000000
# 26004        -1.000000
# 38200        -1.000000
# 50396        -1.000000
# 62592        -1.000000
# 74788        -1.000000
# 86984        -1.000000
# 99180        -1.000000
# 111376       -1.000000
# 123572       -1.000000
# 135768       -1.000000
# 147964       -1.000000
# 160160       -1.000000
# 172356       -1.000000
# 184552       -1.000000
# 196748       -1.000000
# 208944       -1.000000
# 221140       -1.000000
# 233336       -1.000000
# 245532       -1.000000
# 257728       -1.000000
# 269924       -1.000000
# 282120       -1.000000
# 294316       -1.000000
# 306512       -1.000000
# 318708       -1.000000
# 330904       -1.000000
# 343100       -0.857143
# 355296       -0.821429
# 367492       -0.785714
# 379688       -0.714286
# 391884       -0.535714
# 404080       -0.428571
# 416276       -0.392857

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23330948 entries, 0 to 23330947
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              category
#  1   item_id         category
#  2   dept_id         category
#  3   cat_id          category
#  4   store_id        category
#  5   state_id        category
#  6   Sales           int16
#  7   date            object
#  8   wday            int64
#  9   snap_CA         int64
#  10  Lag_28          float64
#  11  rmean_7_lag28   float64
#  12  rmean_28_lag28  float64
# dtypes: category(6), float64(3), int16(1), int64(2), object(1)
# memory usage: 1.3+ GB

# %%
df["date"]=pd.to_datetime(df["date"])

# %%
df.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  Sales       date  wday  snap_CA  Lag_28  rmean_7_lag28  \
# 0       CA      0 2011-01-29     1        0    -1.0           -1.0
# 1       CA      0 2011-01-29     1        0    -1.0           -1.0
# 2       CA      0 2011-01-29     1        0    -1.0           -1.0
# 3       CA      0 2011-01-29     1        0    -1.0           -1.0
# 4       CA      0 2011-01-29     1        0    -1.0           -1.0
#
#    rmean_28_lag28
# 0            -1.0
# 1            -1.0
# 2            -1.0
# 3            -1.0
# 4            -1.0

# %%
date_feats = {

    "wday":"weekday",
    "month":"month",
    "quarter":"quarter",
    "year":"year",
    "mday":"day"
}

for col_name,func_name in date_feats.items():
    if col_name in df.columns:
        df[col_name]=df[col_name].astype("int16")
    else:
        df[col_name] = getattr(df["date"].dt,func_name).astype("int16")

# %%
df.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  Sales       date  wday  snap_CA  Lag_28  rmean_7_lag28  \
# 0       CA      0 2011-01-29     1        0    -1.0           -1.0
# 1       CA      0 2011-01-29     1        0    -1.0           -1.0
# 2       CA      0 2011-01-29     1        0    -1.0           -1.0
# 3       CA      0 2011-01-29     1        0    -1.0           -1.0
# 4       CA      0 2011-01-29     1        0    -1.0           -1.0
#
#    rmean_28_lag28  month  quarter  year  mday
# 0            -1.0      1        1  2011    29
# 1            -1.0      1        1  2011    29
# 2            -1.0      1        1  2011    29
# 3            -1.0      1        1  2011    29
# 4            -1.0      1        1  2011    29

# %%
df["WeekNum"] = df["date"].dt.isocalendar().week

# %%
df.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  Sales       date  wday  snap_CA  Lag_28  rmean_7_lag28  \
# 0       CA      0 2011-01-29     1        0    -1.0           -1.0
# 1       CA      0 2011-01-29     1        0    -1.0           -1.0
# 2       CA      0 2011-01-29     1        0    -1.0           -1.0
# 3       CA      0 2011-01-29     1        0    -1.0           -1.0
# 4       CA      0 2011-01-29     1        0    -1.0           -1.0
#
#    rmean_28_lag28  month  quarter  year  mday  WeekNum
# 0            -1.0      1        1  2011    29        4
# 1            -1.0      1        1  2011    29        4
# 2            -1.0      1        1  2011    29        4
# 3            -1.0      1        1  2011    29        4
# 4            -1.0      1        1  2011    29        4

# %%
df1=df.copy()

# %%
cat_items = [cols for cols in df.columns if df[cols].dtype == "category"]
cat_items
# Out:
# ['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']

# %%
cat_items.remove("id")

# %%
cat_items
# Out:
# ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']

# %%
le=LabelEncoder()
lemap={}
dic={}
for cc in cat_items:
    df1[cc]=le.fit_transform(df1[cc])
    lemap[cc] = {label: encoded for encoded, label in enumerate(le.classes_)}

# %%
lemap
# Out:
# {'item_id': {'FOODS_1_001': 0,
#   'FOODS_1_002': 1,
#   'FOODS_1_003': 2,
#   'FOODS_1_004': 3,
#   'FOODS_1_005': 4,
#   'FOODS_1_006': 5,
#   'FOODS_1_008': 6,
#   'FOODS_1_009': 7,
#   'FOODS_1_010': 8,
#   'FOODS_1_011': 9,
#   'FOODS_1_012': 10,
#   'FOODS_1_013': 11,
#   'FOODS_1_014': 12,
#   'FOODS_1_015': 13,
#   'FOODS_1_016': 14,
#   'FOODS_1_017': 15,
#   'FOODS_1_018': 16,
#   'FOODS_1_019': 17,
#   'FOODS_1_020': 18,
#   'FOODS_1_021': 19,
#   'FOODS_1_022': 20,
#   'FOODS_1_023': 21,
#   'FOODS_1_024': 22,
#   'FOODS_1_025': 23,
#   'FOODS_1_026': 24,
#   'FOODS_1_027': 25,
#   'FOODS_1_028': 26,
#   'FOODS_1_029': 27,
#   'FOODS_1_030': 28,
#   'FOODS_1_031': 29,
#   'FOODS_1_032': 30,
#   'FOODS_1_033': 31,
#   'FOODS_1_034': 32,
#   'FOODS_1_035': 33,
#   'FOODS_1_036': 34,
#   'FOODS_1_037': 35,
#   'FOODS_1_038': 36,
#   'FOODS_1_039': 37,
#   'FOODS_1_040': 38,
#   'FOODS_1_041': 39,
#   'FOODS_1_042': 40,
#   'FOODS_1_043': 41,
#   'FOODS_1_044': 42,
#   'FOODS_1_045': 43,
#   'FOODS_1_046': 44,
#   'FOODS_1_047': 45,
#   'FOODS_1_048': 46,
#   'FOODS_1_049': 47,
#   'FOODS_1_050': 48,
#   'FOODS_1_051': 49,
#   'FOODS_1_052': 50,
#   'FOODS_1_053': 51,
#   'FOODS_1_054': 52,
#   'FOODS_1_055': 53,
#   'FOODS_1_056': 54,
#   'FOODS_1_057': 55,
#   'FOODS_1_058': 56,
#   'FOODS_1_059': 57,
#   'FOODS_1_060': 58,
#   'FOODS_1_061': 59,
#   'FOODS_1_062': 60,
#   'FOODS_1_063': 61,
#   'FOODS_1_064': 62,
#   'FOODS_1_065': 63,
#   'FOODS_1_066': 64,
#   'FOODS_1_067': 65,
#   'FOODS_1_068': 66,
#   'FOODS_1_069': 67,
#   'FOODS_1_070': 68,
#   'FOODS_1_071': 69,
#   'FOODS_1_072': 70,
#   'FOODS_1_073': 71,
#   'FOODS_1_074': 72,
#   'FOODS_1_075': 73,
#   'FOODS_1_076': 74,
#   'FOODS_1_077': 75,
#   'FOODS_1_078': 76,
#   'FOODS_1_079': 77,
#   'FOODS_1_080': 78,
#   'FOODS_1_081': 79,
#   'FOODS_1_082': 80,
#   'FOODS_1_083': 81,
#   'FOODS_1_084': 82,
#   'FOODS_1_085': 83,
#   'FOODS_1_086': 84,
#   'FOODS_1_087': 85,
#   'FOODS_1_088': 86,
#   'FOODS_1_089': 87,
#   'FOODS_1_090': 88,
#   'FOODS_1_091': 89,
#   'FOODS_1_092': 90,
#   'FOODS_1_093': 91,
#   'FOODS_1_094': 92,
#   'FOODS_1_095': 93,
#   'FOODS_1_096': 94,
#   'FOODS_1_097': 95,
#   'FOODS_1_098': 96,
#   'FOODS_1_099': 97,
#   'FOODS_1_101': 98,
#   'FOODS_1_102': 99,
#   'FOODS_1_103': 100,
#   'FOODS_1_104': 101,
#   'FOODS_1_105': 102,
#   'FOODS_1_106': 103,
#   'FOODS_1_107': 104,
#   'FOODS_1_108': 105,
#   'FOODS_1_109': 106,
#   'FOODS_1_110': 107,
#   'FOODS_1_111': 108,
#   'FOODS_1_112': 109,
#   'FOODS_1_113': 110,
#   'FOODS_1_114': 111,
#   'FOODS_1_115': 112,
#   'FOODS_1_116': 113,
#   'FOODS_1_117': 114,
#   'FOODS_1_118': 115,
#   'FOODS_1_119': 116,
#   'FOODS_1_120': 117,
#   'FOODS_1_121': 118,
#   'FOODS_1_122': 119,
#   'FOODS_1_123': 120,
#   'FOODS_1_124': 121,
#   'FOODS_1_125': 122,
#   'FOODS_1_126': 123,
#   'FOODS_1_127': 124,
#   'FOODS_1_128': 125,
#   'FOODS_1_129': 126,
#   'FOODS_1_130': 127,
#   'FOODS_1_131': 128,
#   'FOODS_1_132': 129,
#   'FOODS_1_133': 130,
#   'FOODS_1_134': 131,
#   'FOODS_1_135': 132,
#   'FOODS_1_136': 133,
#   'FOODS_1_137': 134,
#   'FOODS_1_138': 135,
#   'FOODS_1_139': 136,
#   'FOODS_1_140': 137,
#   'FOODS_1_141': 138,
#   'FOODS_1_142': 139,
#   'FOODS_1_143': 140,
#   'FOODS_1_144': 141,
#   'FOODS_1_145': 142,
#   'FOODS_1_146': 143,
#   'FOODS_1_147': 144,
#   'FOODS_1_148': 145,
#   'FOODS_1_149': 146,
#   'FOODS_1_150': 147,
#   'FOODS_1_151': 148,
#   'FOODS_1_152': 149,
#   'FOODS_1_153': 150,
#   'FOODS_1_154': 151,
#   'FOODS_1_155': 152,
#   'FOODS_1_156': 153,
#   'FOODS_1_157': 154,
#   'FOODS_1_158': 155,
#   'FOODS_1_159': 156,
#   'FOODS_1_160': 157,
#   'FOODS_1_161': 158,
#   'FOODS_1_162': 159,
#   'FOODS_1_163': 160,
#   'FOODS_1_164': 161,
#   'FOODS_1_166': 162,
#   'FOODS_1_167': 163,
#   'FOODS_1_168': 164,
#   'FOODS_1_169': 165,
#   'FOODS_1_170': 166,
#   'FOODS_1_171': 167,
#   'FOODS_1_172': 168,
#   'FOODS_1_173': 169,
#   'FOODS_1_174': 170,
#   'FOODS_1_175': 171,
#   'FOODS_1_176': 172,
#   'FOODS_1_177': 173,
#   'FOODS_1_178': 174,
#   'FOODS_1_179': 175,
#   'FOODS_1_180': 176,
#   'FOODS_1_181': 177,
#   'FOODS_1_182': 178,
#   'FOODS_1_183': 179,
#   'FOODS_1_184': 180,
#   'FOODS_1_185': 181,
#   'FOODS_1_186': 182,
#   'FOODS_1_187': 183,
#   'FOODS_1_188': 184,
#   'FOODS_1_189': 185,
#   'FOODS_1_190': 186,
#   'FOODS_1_191': 187,
#   'FOODS_1_192': 188,
#   'FOODS_1_193': 189,
#   'FOODS_1_194': 190,
#   'FOODS_1_195': 191,
#   'FOODS_1_196': 192,
#   'FOODS_1_197': 193,
#   'FOODS_1_198': 194,
#   'FOODS_1_199': 195,
#   'FOODS_3_361': 973,
#   'FOODS_3_362': 974,
#   'FOODS_3_363': 975,
#   'FOODS_3_364': 976,
#   'FOODS_3_365': 977,
#   'FOODS_3_366': 978,
#   'FOODS_3_367': 979,
#   'FOODS_3_368': 980,
#   'FOODS_3_369': 981,
#   'FOODS_3_370': 982,
#   'FOODS_3_371': 983,
#   'FOODS_3_372': 984,
#   'FOODS_3_373': 985,
#   'FOODS_3_374': 986,
#   'FOODS_3_375': 987,
#   'FOODS_3_376': 988,
#   'FOODS_3_377': 989,
#   'FOODS_3_378': 990,
#   'FOODS_3_379': 991,
#   'FOODS_3_380': 992,
#   'FOODS_3_381': 993,
#   'FOODS_3_382': 994,
#   'FOODS_3_383': 995,
#   'FOODS_3_384': 996,
#   'FOODS_3_385': 997,
#   'FOODS_3_386': 998,
#   'FOODS_3_387': 999,
#   ...},
#  'dept_id': {'FOODS_1': 0,
#   'FOODS_2': 1,
#   'FOODS_3': 2,
#   'HOBBIES_1': 3,
#   'HOBBIES_2': 4,
#   'HOUSEHOLD_1': 5,
#   'HOUSEHOLD_2': 6},
#  'cat_id': {'FOODS': 0, 'HOBBIES': 1, 'HOUSEHOLD': 2},
#  'store_id': {'CA_1': 0, 'CA_2': 1, 'CA_3': 2, 'CA_4': 3},
#  'state_id': {'CA': 0}}

# %%
df.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'Sales',
#        'date', 'wday', 'snap_CA', 'Lag_28', 'rmean_7_lag28', 'rmean_28_lag28',
#        'month', 'quarter', 'year', 'mday', 'WeekNum'],
#       dtype='object')

# %%
cutoffdate = df["date"].max()-pd.to_timedelta(28,unit="D")
cutoffdate
# Out:
# Timestamp('2016-03-27 00:00:00')

# %%
Xtrain = df.loc[df.date < cutoffdate].copy()
Xtest = df.loc[df.date >= cutoffdate].copy()

# %%
Xtest.head(2)
# Out:
#                                      id        item_id    dept_id   cat_id  \
# 22977264  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 22977265  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
#
#          store_id state_id  Sales       date  wday  snap_CA  Lag_28  \
# 22977264     CA_1       CA      1 2016-03-27     2        0     2.0
# 22977265     CA_1       CA      1 2016-03-27     2        0     0.0
#
#           rmean_7_lag28  rmean_28_lag28  month  quarter  year  mday  WeekNum
# 22977264       1.714286        1.035714      3        1  2016    27       12
# 22977265       0.142857        0.178571      3        1  2016    27       12

# %%
ytrain = Xtrain['Sales'].copy()
ytest = Xtest['Sales'].copy()

# %%
ytrain
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 22977259    0
# 22977260    0
# 22977261    0
# 22977262    2
# 22977263    1
# Name: Sales, Length: 22977264, dtype: int16

# %% [markdown]
# ## Reason we separately create dtrain and dvalid as LightGBM Dataset objects (instead of using the raw DataFrames xtrain/xvalid directly) is because LightGBM requires its own optimized data structure for efficient training. Here's why this is necessary:
#
# Key Reasons for Using lgb.Dataset
# Memory Optimization
# LightGBM converts the data into a binarized format (histograms) for faster operations. The Dataset object stores this optimized representation.
#
# Preprocessing
# The dataset object handles:
#
# Automatic handling of categorical features
#
# Missing value treatment
#
# Optimal memory layout for the boosting algorithm
#
# Validation Tracking
# The dvalid dataset enables proper validation during training (early stopping, metric evaluation).

# %%
Xtrain.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'Sales',
#        'date', 'wday', 'snap_CA', 'Lag_28', 'rmean_7_lag28', 'rmean_28_lag28',
#        'month', 'quarter', 'year', 'mday', 'WeekNum'],
#       dtype='object')

# %%
Xtrain.drop(['id', 'wday', 'Sales',  'snap_CA', 'year', 'date'], axis = 1, inplace = True)
Xtest.drop(['id', 'wday', 'Sales',  'snap_CA', 'year', 'date'], axis = 1, inplace = True)

# %%
lgbXtrain = lgb.Dataset(Xtrain,label = ytrain, free_raw_data=False)
lgbXtest = lgb.Dataset(Xtrain,label = ytest, free_raw_data=False)

# %%
ytrain
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 22977259    0
# 22977260    0
# 22977261    0
# 22977262    2
# 22977263    1
# Name: Sales, Length: 22977264, dtype: int16

# %%
import seaborn as sns

# %%
params = {
     "objective" : "poisson",
        "metric" : "rmse",
        "learning_rate" : 0.075,
         "feature_fraction" : 0.8,
        "bagging_fraction" : 0.75,
        "bagging_freq" : 1,
        "lambda_l2" : 0.1,
        'verbosity': 1,
       'num_iterations' : 1000,        
        'num_leaves': 64,
        "min_data_in_leaf": 100,
}

# %%
from lightgbm import LGBMRegressor

# %%
m_lgb = LGBMRegressor(**params)

# %%
m_lgb.fit(Xtrain,ytrain,eval_set=[(Xtest,ytest)],callbacks=[lgb.early_stopping(stopping_rounds=100)])
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.496762 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3722
# [LightGBM] [Info] Number of data points in the train set: 22977264, number of used features: 12
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Start training from score 0.203045
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [441]	valid_0's rmse: 2.28553
# LGBMRegressor(bagging_fraction=0.75, bagging_freq=1, feature_fraction=0.8,
#               lambda_l2=0.1, learning_rate=0.075, metric='rmse',
#               min_data_in_leaf=100, num_iterations=1000, num_leaves=64,
#               objective='poisson', verbosity=1)

# %%
m_lgb.best_score_
# Out:
# defaultdict(collections.OrderedDict,
#             {'valid_0': OrderedDict([('rmse', 2.2855327495461117)])})

# %%
m_lgb.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.075,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_leaves': 64,
#  'objective': 'poisson',
#  'random_state': None,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0,
#  'metric': 'rmse',
#  'feature_fraction': 0.8,
#  'bagging_fraction': 0.75,
#  'bagging_freq': 1,
#  'lambda_l2': 0.1,
#  'verbosity': 1,
#  'num_iterations': 1000,
#  'min_data_in_leaf': 100}

# %%
lgb.plot_importance(m_lgb)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
lgb.plot_metric(m_lgb)
# Out:
# <Axes: title={'center': 'Metric during training'}, xlabel='Iterations', ylabel='rmse'>

# %%
lgb.plot_split_value_histogram(m_lgb,feature='month')
# Out:
# <Axes: title={'center': 'Split value histogram for feature with name month'}, xlabel='Feature split value', ylabel='Count'>
