# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_tsla = pdr.get_data_yahoo('TSLA')
df_tsla.head(-5)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-05-25   63.394001   61.562000   62.203999   63.366001  25070000.0
# 2017-05-26   65.098000   63.262001   63.456001   65.028000  39011000.0
# 2017-05-30   67.255997   65.152000   65.199997   67.019997  38914500.0
# 2017-05-31   68.578003   67.031998   67.538002   68.202003  49817000.0
# 2017-06-01   68.975998   67.458000   68.800003   68.073997  38040000.0
# ...                ...         ...         ...         ...         ...
# 2022-05-11  809.770020  727.200012  795.000000  734.000000  32408200.0
# 2022-05-12  759.659973  680.000000  701.000000  728.000000  46771000.0
# 2022-05-13  787.349976  751.570007  773.479980  769.590027  30651800.0
# 2022-05-16  769.760010  719.090027  767.159973  724.369995  28699500.0
# 2022-05-17  764.479980  728.849976  747.359985  761.609985  26745400.0
#
#              Adj Close
# Date
# 2017-05-25   63.366001
# 2017-05-26   65.028000
# 2017-05-30   67.019997
# ...

# %% [markdown]
# ## MA(Rolling) vs WMA vs #EMA
#
# ####  https://www.investopedia.com/ask/answers/071414/whats-difference-between-moving-average-and-weighted-moving-average.asp#:~:text=The%20main%20difference%20between%20simple,more%20weight%20to%20current%20data.

# %% [markdown]
# ## Moving Average

# %%
df_tsla['10 days Rolling - Open'] = df_tsla['Open'].rolling(10,min_periods=2).mean()

# %%
df_tsla[['Open','10 days Rolling - Open']].plot(figsize=(20,10),xlim=['2020-1-5','2021-5-5'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Expanding - Cumulative Moving Avg

# %%
df_tsla['Expanding']=df_tsla['Open'].expanding().mean()

# %%
df_tsla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2017-05-25  63.394001  61.562000  62.203999  63.366001  25070000.0  63.366001
# 2017-05-26  65.098000  63.262001  63.456001  65.028000  39011000.0  65.028000
# 2017-05-30  67.255997  65.152000  65.199997  67.019997  38914500.0  67.019997
# 2017-05-31  68.578003  67.031998  67.538002  68.202003  49817000.0  68.202003
# 2017-06-01  68.975998  67.458000  68.800003  68.073997  38040000.0  68.073997
#
#             10 days Rolling - Open  Expanding
# Date
# 2017-05-25                     NaN  62.203999
# 2017-05-26               62.830000  62.830000
# 2017-05-30               63.619999  63.619999
# 2017-05-31               64.599500  64.599500
# 2017-06-01               65.439600  65.439600

# %% [markdown]
# ## Ewm - Expo. Weighted Moving Avg

# %%
df_tsla['ewma_alpha=0.1']=df_tsla['Open'].ewm(alpha=0.1,adjust=True).mean()
df_tsla['ewma_span=3']=df_tsla['Open'].ewm(span=3,adjust=True).mean()
df_tsla.drop('ewma_span=1',inplace=True,axis=1)

# %%
df_tsla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2017-05-25  63.394001  61.562000  62.203999  63.366001  25070000.0  63.366001
# 2017-05-26  65.098000  63.262001  63.456001  65.028000  39011000.0  65.028000
# 2017-05-30  67.255997  65.152000  65.199997  67.019997  38914500.0  67.019997
# 2017-05-31  68.578003  67.031998  67.538002  68.202003  49817000.0  68.202003
# 2017-06-01  68.975998  67.458000  68.800003  68.073997  38040000.0  68.073997
#
#             10 days Rolling - Open  Expanding  ewma_alpha=0.1  ewma_span=3
# Date
# 2017-05-25                     NaN  62.203999       62.203999    62.203999
# 2017-05-26               62.830000  62.830000       62.862947    63.038667
# 2017-05-30               63.619999  63.619999       63.725327    64.273713
# 2017-05-31               64.599500  64.599500       64.833985    66.014667
# 2017-06-01               65.439600  65.439600       65.802464    67.452260
